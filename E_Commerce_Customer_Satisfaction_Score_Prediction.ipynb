# %% [markdown]
# <a href="https://colab.research.google.com/github/Geeta015/DeepCSAT-E-Commerce-Customer-Satisfaction-Score-Prediction/blob/main/E_Commerce_Customer_Satisfaction_Score_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Done By:
# ## Geeta Rani
# ## Vishal Kumar Yadav
# ## Mukta Barad
# ## Pragyanshu Panda
# ## Saksham Tripathi

# %% [markdown]
# GITHUB Link:

# %% [markdown]
# ## About Dataset
# The dataset captures customer satisfaction scores for a one-month period at an e-commerce platform called Shopzilla (a pseudonym). It includes various features such as category and sub-category of interaction, customer remarks, survey response date, category, item price, agent details (name, supervisor, manager), and CSAT score etc.
#
# ## Dataset Information:
#
# Rows: 85,907
#
# Columns: 20
#
# Usage:
#
# This dataset serves as a valuable resource for conducting Exploratory data analysis (EDA), Visualization, and Machine Learning Classification tasks pertaining to customer service performance evaluation, satisfaction forecasting, and customer behavior analysis within the e-commerce sector.
#
# Do explore pinned 📌 notebook under code section for quick EDA📊 reference
# Consider an upvote ^ if you find the dataset useful
#
# ## Data Description:
#
# Unique id:	Unique identifier for each record
#
# Channel name:	Name of the customer service channel
#
# Category:	Category of the interaction
#
# Sub-category:	Sub-category of the interaction
#
# Customer Remarks:	Feedback provided by the customer
#
# Order id:	Identifier for the order associated with the interaction
#
# Order date time:	Date and time of the order
#
# Issue reported at:	Timestamp when the issue was reported
#
# Issue responded:	Timestamp when the issue was responded to
#
# Survey response date:	Date of the customer survey response
#
# Customer city:	City of the customer
#
# Product category:	Category of the product
#
# Item price:	Price of the item
#
# Connected handling time:	Time taken to handle the interaction
#
# Agent name:	Name of the customer service agent
#
# Supervisor:	Name of the supervisor
#
# Manager:	Name of the manager
#
# Tenure Bucket:	Bucket categorizing agent tenure
#
# Agent Shift:	Shift timing of the agent
#
# CSAT Score:	Customer Satisfaction (CSAT) score

# %%
# Mount Google Drive to access files stored in your Google Drive from Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import libraries for data manipulation, visualization, and preprocessing

# Import NumPy for numerical operations
import numpy as np

# Import pandas for data manipulation and analysis
import pandas as pd

# Import Matplotlib for creating static, interactive, and animated visualizations
import matplotlib.pyplot as plt

# Import Seaborn for statistical data visualization
import seaborn as sns

# Import warnings to control the display of warning messages
import warnings
warnings.filterwarnings("ignore")  # Ignore warnings during execution

# Import zipfile for handling zip files
import zipfile

# Import FunctionTransformer for transforming features with custom functions
from sklearn.preprocessing import FunctionTransformer

# Import scipy.stats for statistical functions and distributions
import scipy.stats as stats

# %%
#Extract, read data and Create data frame
df=pd.read_csv('/content/drive/MyDrive/eCommerce_Customer_support_data.csv')

# %%
# Display the first 5 rows of the DataFrame to preview its structure and data
df.head()
# Out:
#                               Unique id channel_name         category  \
# 0  7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1  b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2  200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3  eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4  ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
#
#                    Sub-category Customer Remarks  \
# 0                Life Insurance              NaN
# 1  Product Specific Information              NaN
# 2             Installation/demo              NaN
# 3        Reverse Pickup Enquiry              NaN
# 4                    Not Needed              NaN
#
#                                Order_id order_date_time Issue_reported at  \
# 0  c27c9bb4-fa36-4140-9f1f-21009254ffdb             NaN  01/08/2023 11:13
# 1  d406b0c7-ce17-4654-b9de-f08d421254bd             NaN  01/08/2023 12:52
# ...

# %%
# Print the number of rows and columns in the DataFrame
print("This data set has", df.shape[0], "rows and", df.shape[1], "columns.")
# Out:
# This data set has 85907 rows and 20 columns.

# %%
# Display information about the DataFrame, including the data types and non-null counts for each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85907 entries, 0 to 85906
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unique id                85907 non-null  object
#  1   channel_name             85907 non-null  object
#  2   category                 85907 non-null  object
#  3   Sub-category             85907 non-null  object
#  4   Customer Remarks         28742 non-null  object
#  5   Order_id                 67675 non-null  object
#  6   order_date_time          17214 non-null  object
#  7   Issue_reported at        85907 non-null  object
#  8   issue_responded          85907 non-null  object
#  9   Survey_response_Date     85907 non-null  object
#  10  Customer_City            17079 non-null  object
#  11  Product_category         17196 non-null  object
#  12  Item_price               17206 non-null  float64
#  13  connected_handling_time  242 non-null    float64
# ...

# %% [markdown]
# Based on data set info. This df has dumped with 85907 rows and 20 Columns.
#
# Except 3 variable such as (Item_price, Connected_handling_time and CSAT Score) all other variables seems to be Object data type.
#
# The data shows like non-null but as per count in some variable, many data might be fill with NAN, NA or some other charecters.

# %%
# Provide a summary of statistics for numerical columns in the DataFrame, with rows and columns transposed for easier reading
df.describe().T
# Out:
#                            count         mean           std  min    25%  \
# Item_price               17206.0  5660.774846  12825.728411  0.0  392.0
# connected_handling_time    242.0   462.400826    246.295037  0.0  293.0
# CSAT Score               85907.0     4.242157      1.378903  1.0    4.0
#
#                            50%      75%       max
# Item_price               979.0  2699.75  164999.0
# connected_handling_time  427.0   592.25    1986.0
# CSAT Score                 5.0     5.00       5.0

# %% [markdown]
# Describe is actually an 5 point summary which will calculate for numerical values. So the reason only 3 variable got described.
#
# * Item_price and connected_handling_time has its bell shape curve with a huge left skewness. and these both seems to have too many outlier, which can be clearly explained in visualization.
#
# * CSAT variable has numerical Dtype but it looks like a categorical variable.

# %%
# Print the count of unique values for each column in the DataFrame to understand the distribution of categorical data
for i in df.columns:
    print(df[i].value_counts())
# Out:
# Unique id
# 7e9ae164-6a8b-4521-a2d4-58f7c9fff13f    1
# 4a7fec30-68f5-4891-b934-6a666e00930e    1
# 67792991-fd16-465f-bbdc-3189a0f16395    1
# c629cb55-3c2b-448c-8598-96eeb0f30f13    1
# 67f2636b-055f-4ae5-a360-c3f35c09205c    1
#                                        ..
# 71c4d872-ed1a-4215-98fc-0753046c7637    1
# 8ae06ce2-ffd7-4c5f-9820-56226ec30275    1
# 52b3f399-ee61-41fa-b332-d830ab176977    1
# 4c9be137-c6ea-48ea-b80b-5b5dda67110d    1
# 07c7a878-0d5a-42e0-97ef-de59abec0238    1
# Name: count, Length: 85907, dtype: int64
# channel_name
# Inbound    68142
# Outcall    14742
# Email       3023
# Name: count, dtype: int64
# category
# Returns               44097
# Order Related         23215
# Refund Related         4550
# Product Queries        3692
# Shopzilla Related      2792
# Payments related       2327
# Feedback               2294
# Cancellation           2212
# Offers & Cashback       480
# Others                   99
# App/website              84
# ...

# %%
#finding duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# Calculate the percentage of missing values and count of unique values for each column
null_values = round(df.isnull().sum() * 100 / len(df), 2)  # Percentage of missing values
unique_values = df.nunique()  # Count of unique values in each column

# Create a DataFrame to summarize the analysis of null values, unique values, and data types for each column
analysis_df = pd.DataFrame({
    'column_name': df.columns,         # Column names
    'unique_values': unique_values,    # Number of unique values
    'null_values_%': null_values,      # Percentage of null values
    'data_type': df.dtypes              # Data type of each column
})

# Reset index for the new DataFrame
analysis_df.reset_index(drop=True, inplace=True)

# Display the summary DataFrame
analysis_df
# Out:
#                 column_name  unique_values  null_values_% data_type
# 0                 Unique id          85907           0.00    object
# 1              channel_name              3           0.00    object
# 2                  category             12           0.00    object
# 3              Sub-category             57           0.00    object
# 4          Customer Remarks          18231          66.54    object
# 5                  Order_id          67675          21.22    object
# 6           order_date_time          13766          79.96    object
# 7         Issue_reported at          30923           0.00    object
# 8           issue_responded          30262           0.00    object
# 9      Survey_response_Date             31           0.00    object
# 10            Customer_City           1782          80.12    object
# 11         Product_category              9          79.98    object
# 12               Item_price           2789          79.97   float64
# ...

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# By looking above analysis we could notice categories such as Unique ID, Customer Remark and Order_ID wont be usefull for further analysis so we suppose to drope those Variables.
#
# Some object variables looks to be like time stamp columns. So the data type need to get change for those variables.
#
# Some Object and float dtype variables has filled with NAN. Those needs to get filled as per needs.

# %%
# Drop columns that are not needed for analysis
df1 = df.drop(["Unique id", "Customer Remarks", "Order_id", "order_date_time"], axis=1)

# Display a random sample of 2 rows from the updated DataFrame to verify the result
df1.sample(n=2)
# Out:
#       channel_name category            Sub-category Issue_reported at  \
# 83723      Outcall  Returns                   Wrong  30/08/2023 18:54
# 13539      Inbound  Returns  Reverse Pickup Enquiry  05/08/2023 15:32
#
#         issue_responded Survey_response_Date Customer_City Product_category  \
# 83723  31/08/2023 05:29            31-Aug-23           NaN              NaN
# 13539  06/08/2023 19:41            06-Aug-23           NaN              NaN
#
#        Item_price  connected_handling_time        Agent_name  Supervisor  \
# 83723         NaN                      NaN       Stephen Lee  Noah Patel
# 13539         NaN                      NaN  Brian Wilson PhD   Emma Park
#
#            Manager Tenure Bucket Agent Shift  CSAT Score
# 83723  Michael Lee           >90     Morning           5
# 13539   John Smith         31-60     Morning           5

# %%
# Convert specified columns with object data type to datetime data type
col = ['Issue_reported at', 'issue_responded', 'Survey_response_Date']
for i in col:
    df1[i] = pd.to_datetime(df1[i], dayfirst=True)  # Convert to datetime format with day first
    print(i, ": dtype =", df1[i].dtype)  # Print the column name and its new data type
# Out:
# Issue_reported at : dtype = datetime64[ns]
# issue_responded : dtype = datetime64[ns]
# Survey_response_Date : dtype = datetime64[ns]

# %%
# Fill null values in the DataFrame based on the data type of each column
for i in df1.columns:
    if df1[i].isnull().sum() > 0:  # Check if there are any null values in the column
        if df1[i].dtype == "object":
            # For object (categorical) columns, replace null values with "Unknown"
            df1[i].fillna("Unknown", inplace=True)
            print(i, "Variable has object dtype, so it got Replace its null values to Unknown \n")
        elif df1[i].dtype == "float64":
            # For float columns, replace null values with the median of the column
            df1[i].fillna(df1[i].median(), inplace=True)
            print(i, "Variable has float dtype, so it got Replace its null values to columns median value \n")
# Out:
# Customer_City Variable has object dtype, so it got Replace its null values to Unknown
#
# Product_category Variable has object dtype, so it got Replace its null values to Unknown
#
# Item_price Variable has float dtype, so it got Replace its null values to columns median value
#
# connected_handling_time Variable has float dtype, so it got Replace its null values to columns median value

# %%
# Calculate the percentage of missing values and count of unique values for each column in the cleaned DataFrame
null_values1 = round(df1.isnull().sum() * 100 / len(df1), 2)  # Percentage of null values
unique_values1 = df1.nunique()  # Count of unique values in each column

# Create a DataFrame to summarize the analysis of null values, unique values, and data types for each column
analysis_df1 = pd.DataFrame({
    'column_name': df1.columns,         # Column names
    'unique_values': unique_values1,    # Number of unique values
    'null_values_%': null_values1,      # Percentage of null values
    'data_type': df1.dtypes              # Data type of each column
})

# Reset index for the new DataFrame
analysis_df1.reset_index(drop=True, inplace=True)

# Display the summary DataFrame
analysis_df1
# Out:
#                 column_name  unique_values  null_values_%       data_type
# 0              channel_name              3            0.0          object
# 1                  category             12            0.0          object
# 2              Sub-category             57            0.0          object
# 3         Issue_reported at          30923            0.0  datetime64[ns]
# 4           issue_responded          30262            0.0  datetime64[ns]
# 5      Survey_response_Date             31            0.0  datetime64[ns]
# 6             Customer_City           1783            0.0          object
# 7          Product_category             10            0.0          object
# 8                Item_price           2789            0.0         float64
# 9   connected_handling_time            211            0.0         float64
# 10               Agent_name           1371            0.0          object
# 11               Supervisor             40            0.0          object
# ...

# %%
# Display information about the DataFrame, including the data types and non-null counts for each column
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85907 entries, 0 to 85906
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   channel_name             85907 non-null  object
#  1   category                 85907 non-null  object
#  2   Sub-category             85907 non-null  object
#  3   Issue_reported at        85907 non-null  datetime64[ns]
#  4   issue_responded          85907 non-null  datetime64[ns]
#  5   Survey_response_Date     85907 non-null  datetime64[ns]
#  6   Customer_City            85907 non-null  object
#  7   Product_category         85907 non-null  object
#  8   Item_price               85907 non-null  float64
#  9   connected_handling_time  85907 non-null  float64
#  10  Agent_name               85907 non-null  object
#  11  Supervisor               85907 non-null  object
#  12  Manager                  85907 non-null  object
# ...

# %% [markdown]
# Now the data looks clean, lets move further for analysis.

# %%
# Select a subset of columns from the DataFrame `df1`
#retain only the nesessory featurs for the app
df1=df1[["channel_name","Tenure Bucket","Item_price","CSAT Score"]]

# %%
# Apply one-hot encoding to 'channel_name' and 'Tenure Bucket' (categorical) columns, dropping the first category for each
df1_=pd.get_dummies(df1,columns=["channel_name","Tenure Bucket"],drop_first=True)

# %%
# Import the StandardScaler from scikit-learn to standardize numerical features
from sklearn.preprocessing import StandardScaler

# Create an instance of the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the 'Item_price' column in the DataFrame to learn its mean and standard deviation
scaler.fit(df1_[["Item_price"]])

# Transform the 'Item_price' column in the DataFrame to have a mean of 0 and a standard deviation of 1
df1_numerical_scaled = scaler.transform(df1_[["Item_price"]])

# Convert the scaled 'Item_price' values back into a DataFrame with the same column name
df1_numerical_scaled = pd.DataFrame(df1_numerical_scaled, columns=["Item_price"])

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()

# # fit the scaler to the train set, it will learn the parameters
# scaler.fit(df1_[["Item_price","connected_handling_time"]])

# # transform train and test sets
# df1_numerical_scaled = scaler.transform(df1_[["Item_price","connected_handling_time"]])
# df1_numerical_scaled=pd.DataFrame(df1_numerical_scaled,columns=["Item_price","connected_handling_time"])

# %%
# Combine the one-hot encoded columns with the scaled 'Item_price' and exclude the first column
df1_main = pd.concat([df1_, df1_numerical_scaled], axis=1).iloc[:, 1:]

# %%
# Import TensorFlow library for building and training machine learning models
import tensorflow

# Import Keras API from TensorFlow for building neural network models
from tensorflow import keras

# Import Sequential model class from Keras for building a linear stack of layers
from tensorflow.keras import Sequential

# Import Dense and Flatten layers for creating and configuring the neural network
from tensorflow.keras.layers import Dense, Flatten

# %%
# Separate the features (X) from the target variable (y), where 'CSAT Score' is the target
X = df1_main.drop(columns=['CSAT Score'])
y = df1_main['CSAT Score'].values

# Import train_test_split function to divide the dataset into training and testing sets
from sklearn.model_selection import train_test_split

# Split the data into training (80%) and testing (20%) sets with a fixed random seed for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Import the Sequential model and layer types from Keras for building the neural network
from keras.models import Sequential
from keras.layers import Dense, Flatten, LeakyReLU

# Initialize a Sequential model, which allows stacking layers in a linear fashion
model = Sequential()

# Add a Flatten layer to reshape the input into a 1D array
model.add(Flatten(input_shape=(7, 1)))

# Add the first Dense layer with 128 units followed by a Leaky ReLU activation function
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.01))

# Add additional Dense layers with 128 units and Leaky ReLU activation
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.01))
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.01))
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.01))
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.01))

# Add the output Dense layer with 6 units (one for each class) and a softmax activation function
model.add(Dense(6, activation='softmax'))

# Display the summary of the model architecture, including the number of layers and parameters
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)                  │ (None, 7)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 128)                 │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)           │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 128)                 │          16,512 │
# ...

# %%
# Configure the model with a loss function for classification, an optimizer for adjusting learning, and accuracy as a performance metric
model.compile(loss='sparse_categorical_crossentropy', optimizer='Adagrad', metrics=['accuracy'])

# %%
# Train the model using the training data for 25 epochs and validate its performance on 20% of the training data
history = model.fit(X_train, y_train, epochs=25, validation_split=0.2)
# Out:
# Epoch 1/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6626 - loss: 1.3681 - val_accuracy: 0.6957 - val_loss: 0.9641
# Epoch 2/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.6909 - loss: 0.9698 - val_accuracy: 0.6953 - val_loss: 0.9524
# Epoch 3/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.6908 - loss: 0.9626 - val_accuracy: 0.6953 - val_loss: 0.9501
# Epoch 4/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6936 - loss: 0.9548 - val_accuracy: 0.6952 - val_loss: 0.9490
# Epoch 5/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6935 - loss: 0.9531 - val_accuracy: 0.6952 - val_loss: 0.9483
# Epoch 6/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6949 - loss: 0.9477 - val_accuracy: 0.6950 - val_loss: 0.9477
# Epoch 7/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6943 - loss: 0.9455 - val_accuracy: 0.6953 - val_loss: 0.9473
# Epoch 8/25
# ...

# %%
# Use the trained model to make predictions on the test data
y_prob = model.predict(X_test)
# Out:
# 537/537 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
# Convert the predicted probabilities into class labels by selecting the highest probability for each prediction
y_pred = y_prob.argmax(axis=1)

# %%
# Calculate the accuracy of the model by comparing the predicted labels to the actual labels from the test data
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.6909556512629496

# %%
# Install the Gradio library, which is used to create user-friendly web interfaces for machine learning models
# !pip3 install gradio

# %%
# Import the Gradio library for creating interactive web interfaces
import gradio as gr

# Define a function to make predictions based on user input
def predict(feature1, feature2, feature3, feature4, feature5, feature6, feature7):
    # Convert "True"/"False" inputs to binary values (1 or 0)
    features_np = [
        1 if feature1 == "True" else 0,
        1 if feature2 == "True" else 0,
        1 if feature3 == "True" else 0,
        1 if feature4 == "True" else 0,
        1 if feature5 == "True" else 0,
        1 if feature6 == "True" else 0,
    ]

    # Convert 'Item_price' input to a float and scale it
    feature7 = np.array([[feature7]])
    feature7 = scaler.transform(feature7)[0, 0]

    # Combine features into a single array and reshape for prediction
    features_np = features_np + [feature7]
    features_np = np.array(features_np).reshape(1, -1)

    # Use the model to predict the class based on input features
    prediction = model.predict(features_np)
    predicted_class = np.argmax(prediction, axis=1)
    return str(predicted_class[0])  # Convert the predicted class to a string for display

# Create a Gradio interface to allow users to interact with the prediction function
interface = gr.Interface(
    fn=predict,  # The function that makes predictions
    inputs=[
        gr.Radio(choices=["True", "False"], label="channel_name_Inbound"),  # Radio buttons for 'channel_name_Inbound'
        gr.Radio(choices=["True", "False"], label="channel_name_Outcall"),  # Radio buttons for 'channel_name_Outcall'
        gr.Radio(choices=["True", "False"], label="Tenure Bucket_31-60"),  # Radio buttons for 'Tenure Bucket_31-60'
        gr.Radio(choices=["True", "False"], label="Tenure Bucket_61-90"),  # Radio buttons for 'Tenure Bucket_61-90'
        gr.Radio(choices=["True", "False"], label="Tenure Bucket_>90"),  # Radio buttons for 'Tenure Bucket_>90'
        gr.Radio(choices=["True", "False"], label="Tenure Bucket_On Job Training"),  # Radio buttons for 'Tenure Bucket_On Job Training'
        gr.Textbox(label="Item_price", type="text")  # Textbox for entering 'Item_price'
    ],
    outputs=gr.Textbox(label="CSAT Score"),  # Display the predicted CSAT score
    title="eCommerce Customer Service Satisfaction App",  # Title of the app
    description="Please enter all the values to predict CSAT Score"  # Description of the app
)

# Launch the Gradio interface so users can interact with the app
interface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://6511f969017ccb849b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6511f969017ccb849b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
